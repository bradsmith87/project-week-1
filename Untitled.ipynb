# %%
# Dependencies
import requests
import json

# %%
# URL for GET requests to retrieve vehicle data
#Perth ID
perth_id = 296
apikey ="f98921da60b71947056633acb25f5147"
#url = f"https://developers.zomato.com/api/v2.1/restaurant?res_id=296"
search_url = f"https://developers.zomato.com/api/v2.1/search?entity_id={perth_id}&entity_type=city&start=0"
print(requests.get(search_url, headers={"user-key" : apikey}))
# Out:
# <Response [200]>

# %%
# Retrieving data and converting it into JSON
data = requests.get(search_url, headers={"user-key" : apikey}).json()
#display data structure
data
# Out:
# {'results_found': 5228,
#  'results_start': 0,
#  'results_shown': 20,
#  'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': -1,
#       'takeaway': -1},
#      'res_id': 16600038,
#      'is_grocery_store': False},
#     'apikey': 'f98921da60b71947056633acb25f5147',
#     'id': '16600038',
#     'name': 'Bib & Tucker',
#     'url': 'https://www.zomato.com/perth/bib-tucker-north-fremantle?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '18 Leighton Beach Boulevard, North Fremantle, North Fremantle, Perth',
#      'locality': 'North Fremantle',
#      'city': 'Perth',
#      'city_id': 296,
#      'latitude': '-32.0284215000',
#      'longitude': '115.7498293000',
#      'zipcode': '6159',
#      'country_id': 14,
#      'locality_verbose': 'North Fremantle'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Modern Australian, Cafe Food',
# ...

# %%
resto_num = data["results_found"]
print(f"Number of Rest: {resto_num}")
# Out:
# Number of Rest: 5228

# %%
#print(json.dumps(data, indent=4, sort_keys=True))

rest_name_list =[]
resto_num = 20
loop_num = 0
show_page = 0


for page in range(5):
    for count in range(resto_num):
        rest_name = data["restaurants"][count]["restaurant"]["name"]
        rest_name_list.append(rest_name)
        
        #go to next page
        if count == 19:
            show_page = show_page + 10
            search_url = f"https://developers.zomato.com/api/v2.1/search?entity_id={perth_id}&entity_type=city&start={show_page}"
            data = requests.get(search_url, headers={"user-key" : apikey}).json()
            count = 0

len(rest_name_list)
# Out:
# 100
